# %% [markdown]
# ##  Imports

# %%
import pandas as pd
import requests
import json
import matplotlib
# %matplotlib inline

# %% [markdown]
# # Bitcoin market value for last 30 days, vs. USD, deliver a DF and a Plot

# %%
base = 'https://api.coingecko.com/api/v3/'

# %%
url = base + 'coins/bitcoin/market_chart?vs_currency=usd&days=30'

# %%
apiresult = requests.get(url)
j_bc = apiresult.json()

# %%
# what does j_bc['prices'] here stand for
df_bc=pd.DataFrame(j_bc['prices'],columns=['time','price'])

# %%
df_bc['time'] = pd.to_datetime(df_bc['time'],unit='ms')

# %%
df_bc.set_index('time', inplace=True)

# %%
df_bc.plot()

# %% [markdown]
# # Litecoin market value for last 30 days, vs. USD, deliver a DF and a Plot

# %%
base = 'https://api.coingecko.com/api/v3/'

# %%
url2 = base + 'coins/litecoin/market_chart?vs_currency=usd&days=30'

# %%
literesult = requests.get(url2)
j_lc = literesult.json()

# %%
df_lc=pd.DataFrame(j_lc['prices'],columns=['time','price'])

# %%
df_lc['time'] = pd.to_datetime(df_lc['time'],unit='ms')

# %%
df_lc.set_index('time', inplace=True)

# %%
df_lc.plot()

# %% [markdown]
# ## Plot Litecoin and Dogecoin prices in USD in a lineplot for each for the last 30 days

# %%
base = 'https://api.coingecko.com/api/v3/'
url3 = base + 'coins/dogecoin/market_chart?vs_currency=usd&days=30'

# %%
dogeresult = requests.get(url3)
j_dc = dogeresult.json()

# %%
df_dc=pd.DataFrame(j_dc['prices'],columns=['time','price'])

# %%
df_dc['time'] = pd.to_datetime(df_dc['time'],unit='ms')

# %%
df_dc.set_index('time', inplace=True)

# %%
df_dc.plot()

# %%
import matplotlib.pyplot as plt
fig, ax1 = plt.subplots()
df_lc.plot(ax=ax1)
df_dc.plot(ax=ax1)

# %%
ax = df_bc.plot()
df_lc.plot(ax=ax)

# %% [markdown]
# # Top Ten Coins Report

# %% [markdown]
# ## List the first 10 coingecko currencies in a DataFrame

# %%
url = base + 'coins/list'
result = requests.get(url)
j = result.json()

df_list = pd.DataFrame(j)
df_list.head(10)
# Out:
#                               id    symbol                           name
# 0                         01coin       zoc                         01coin
# 1       0-5x-long-algorand-token  algohalf       0.5X Long Algorand Token
# 2  0-5x-long-altcoin-index-token   althalf  0.5X Long Altcoin Index Token
# 3       0-5x-long-balancer-token   balhalf       0.5X Long Balancer Token
# 4        0-5x-long-bilibra-token  trybhalf         0.5X Long BiLira Token
# 5   0-5x-long-bitcoin-cash-token   bchhalf   0.5X Long Bitcoin Cash Token
# 6     0-5x-long-bitcoin-sv-token   bsvhalf     0.5X Long Bitcoin SV Token
# 7        0-5x-long-bitcoin-token      half        0.5X Long Bitcoin Token
# 8   0-5x-long-bitmax-token-token  btmxhalf   0.5X Long BitMax Token Token
# 9            0-5x-long-bnb-token   bnbhalf            0.5X Long BNB Token

# %% [markdown]
# ## Make a csv called 'top_ten_report.csv' and check that it worked

# %%
df_list.head(10).to_csv('top_ten_report.csv')

# %%
checkcsv = pd.read_csv('top_ten_report.csv')
checkcsv
# Out:
#    Unnamed: 0                             id    symbol  \
# 0           0                         01coin       zoc
# 1           1       0-5x-long-algorand-token  algohalf
# 2           2  0-5x-long-altcoin-index-token   althalf
# 3           3       0-5x-long-balancer-token   balhalf
# 4           4        0-5x-long-bilibra-token  trybhalf
# 5           5   0-5x-long-bitcoin-cash-token   bchhalf
# 6           6     0-5x-long-bitcoin-sv-token   bsvhalf
# 7           7        0-5x-long-bitcoin-token      half
# 8           8   0-5x-long-bitmax-token-token  btmxhalf
# 9           9            0-5x-long-bnb-token   bnbhalf
#
#                             name
# 0                         01coin
# 1       0.5X Long Algorand Token
# 2  0.5X Long Altcoin Index Token
# 3       0.5X Long Balancer Token
# 4         0.5X Long BiLira Token
# 5   0.5X Long Bitcoin Cash Token
# 6     0.5X Long Bitcoin SV Token
# 7        0.5X Long Bitcoin Token
# 8   0.5X Long BitMax Token Token
# ...
