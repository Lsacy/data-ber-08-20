# %%
import pandas as pd
df = pd.read_csv('WordsByCharacter.csv')

# %%
df
# Out:
#                            Film                 Chapter  Character    Race  \
# 0    The Fellowship Of The Ring            01: Prologue      Bilbo  Hobbit
# 1    The Fellowship Of The Ring            01: Prologue     Elrond     Elf
# 2    The Fellowship Of The Ring            01: Prologue  Galadriel     Elf
# 3    The Fellowship Of The Ring            01: Prologue     Gollum  Gollum
# 4    The Fellowship Of The Ring  02: Concerning Hobbits      Bilbo  Hobbit
# ..                          ...                     ...        ...     ...
# 726      The Return Of The King     76: The Grey Havens     Elrond     Elf
# 727      The Return Of The King     76: The Grey Havens      Frodo  Hobbit
# 728      The Return Of The King     76: The Grey Havens  Galadriel     Elf
# 729      The Return Of The King     76: The Grey Havens    Gandalf   Ainur
# 730      The Return Of The King     76: The Grey Havens        Sam  Hobbit
#
#      Words
# 0        4
# 1        5
# 2      460
# 3       20
# ...

# %%
df.index.names
# Out:
# FrozenList([None])

# %%
df.columns
# Out:
# Index(['Film', 'Chapter', 'Character', 'Race', 'Words'], dtype='object')

# %% [raw]
# df.loc[('The Fellowship Of The Ring','01: Prologue'), :]
# df

# %%
df = df.set_index(['Film','Chapter','Race','Character'])

# %%
df
# Out:
#                                                                     Words
# Film                       Chapter                Race   Character
# The Fellowship Of The Ring 01: Prologue           Hobbit Bilbo          4
#                                                   Elf    Elrond         5
#                                                          Galadriel    460
#                                                   Gollum Gollum        20
#                            02: Concerning Hobbits Hobbit Bilbo        214
# ...                                                                   ...
# The Return Of The King     76: The Grey Havens    Elf    Elrond         6
#                                                   Hobbit Frodo        132
#                                                   Elf    Galadriel     17
#                                                   Ainur  Gandalf       42
#                                                   Hobbit Sam           14
#
# ...

# %%
df.index.names
# Out:
# FrozenList(['Film', 'Chapter', 'Race', 'Character'])

# %%
x = df.index.values
type(x)
# Out:
# numpy.ndarray

# %%
df = df.reset_index()

# %%
df = df.set_index(['Film','Chapter','Race','Character']).sort_index()
df.head(20)
# Out:
#                                                                                        Words
# Film                       Chapter                   Race   Character
# The Fellowship Of The Ring 01: Prologue              Elf    Elrond                         5
#                                                             Galadriel                    460
#                                                      Gollum Gollum                        20
#                                                      Hobbit Bilbo                          4
#                            02: Concerning Hobbits    Hobbit Bilbo                        214
#                            03: The Shire             Ainur  Gandalf                      197
#                                                      Hobbit Bilbo                         70
#                                                             Frodo                        128
# ...

# %%
df.loc[('The Fellowship Of The Ring', '03: The Shire', 'Hobbit')]
# Out:
#              Words
# Character
# Bilbo           70
# Frodo          128
# Hobbit Kids     10
# Hobbits         12

# %%
df = df.reset_index()

# %%
df = df.set_index(['Film','Chapter','Race','Character']).sort_index()

# %%
df.loc[('The Fellowship Of The Ring', '01: Prologue')]
# Out:
#                   Words
# Race   Character
# Elf    Elrond         5
#        Galadriel    460
# Gollum Gollum        20
# Hobbit Bilbo          4

# %%
df
# Out:
#                                                                                                Words
# Film                       Chapter                                           Race   Character
# The Fellowship Of The Ring 01: Prologue                                      Elf    Elrond         5
#                                                                                     Galadriel    460
#                                                                              Gollum Gollum        20
#                                                                              Hobbit Bilbo          4
#                            02: Concerning Hobbits                            Hobbit Bilbo        214
# ...                                                                                              ...
# The Two Towers             65: The Battle For Middle Earth Is About To Begin Hobbit Sam           69
# ...

# %%
df.loc[('The Two Towers',slice(None),'Elf')]
# Out:
#                                                                   Words
# Film           Chapter                            Race Character
# The Two Towers 05: The Three Hunters              Elf  Legolas       25
#                09: On The Trail Of The Uruk-Hai   Elf  Legolas       13
#                10: Night Camp At Fangorn          Elf  Legolas       10
#                11: The Riders Of Rohan            Elf  Legolas        7
#                15: The White Rider                Elf  Legolas       63
#                33: The Evenstar                   Elf  Arwen        119
#                                                        Elrond        55
#                34: The Wolves Of Isengard         Elf  Legolas        5
#                37: The Grace Of The Valar         Elf  Arwen          8
#                38: Arwen's Fate                   Elf  Arwen         14
#                                                        Elrond       188
# ...

# %%
df.xs('Orc',level='Race').sum()
# Out:
# Words    723
# dtype: int64

# %%
df = df.reset_index()
df
# Out:
#                            Film  \
# 0    The Fellowship Of The Ring
# 1    The Fellowship Of The Ring
# 2    The Fellowship Of The Ring
# 3    The Fellowship Of The Ring
# 4    The Fellowship Of The Ring
# ..                          ...
# 726              The Two Towers
# 727              The Two Towers
# 728              The Two Towers
# 729              The Two Towers
# 730              The Two Towers
#
#                                                Chapter    Race  Character  \
# 0                                         01: Prologue     Elf     Elrond
# 1                                         01: Prologue     Elf  Galadriel
# 2                                         01: Prologue  Gollum     Gollum
# 3                                         01: Prologue  Hobbit      Bilbo
# 4                               02: Concerning Hobbits  Hobbit      Bilbo
# ..                                                 ...     ...        ...
# ...

# %%
df = df.set_index(i for i in range(1, len(df)+1))
df
# Out:
#                            Film  \
# 1    The Fellowship Of The Ring
# 2    The Fellowship Of The Ring
# 3    The Fellowship Of The Ring
# 4    The Fellowship Of The Ring
# 5    The Fellowship Of The Ring
# ..                          ...
# 727              The Two Towers
# 728              The Two Towers
# 729              The Two Towers
# 730              The Two Towers
# 731              The Two Towers
#
#                                                Chapter    Race  Character  \
# 1                                         01: Prologue     Elf     Elrond
# 2                                         01: Prologue     Elf  Galadriel
# 3                                         01: Prologue  Gollum     Gollum
# 4                                         01: Prologue  Hobbit      Bilbo
# 5                               02: Concerning Hobbits  Hobbit      Bilbo
# ..                                                 ...     ...        ...
# ...

# %%
df.index.name = 'id'

# %%
df
# Out:
#                            Film  \
# id
# 1    The Fellowship Of The Ring
# 2    The Fellowship Of The Ring
# 3    The Fellowship Of The Ring
# 4    The Fellowship Of The Ring
# 5    The Fellowship Of The Ring
# ..                          ...
# 727              The Two Towers
# 728              The Two Towers
# 729              The Two Towers
# 730              The Two Towers
# 731              The Two Towers
#
#                                                Chapter    Race  Character  \
# id
# 1                                         01: Prologue     Elf     Elrond
# 2                                         01: Prologue     Elf  Galadriel
# 3                                         01: Prologue  Gollum     Gollum
# 4                                         01: Prologue  Hobbit      Bilbo
# 5                               02: Concerning Hobbits  Hobbit      Bilbo
# ..                                                 ...     ...        ...
# ...

# %%
df.drop(['Race'],axis=1)
# Out:
#                            Film  \
# id
# 1    The Fellowship Of The Ring
# 2    The Fellowship Of The Ring
# 3    The Fellowship Of The Ring
# 4    The Fellowship Of The Ring
# 5    The Fellowship Of The Ring
# ..                          ...
# 727              The Two Towers
# 728              The Two Towers
# 729              The Two Towers
# 730              The Two Towers
# 731              The Two Towers
#
#                                                Chapter  Character  Words
# id
# 1                                         01: Prologue     Elrond      5
# 2                                         01: Prologue  Galadriel    460
# 3                                         01: Prologue     Gollum     20
# 4                                         01: Prologue      Bilbo      4
# 5                               02: Concerning Hobbits      Bilbo    214
# ..                                                 ...        ...    ...
# ...

# %%
df
# Out:
#                            Film  \
# id
# 1    The Fellowship Of The Ring
# 2    The Fellowship Of The Ring
# 3    The Fellowship Of The Ring
# 4    The Fellowship Of The Ring
# 5    The Fellowship Of The Ring
# ..                          ...
# 727              The Two Towers
# 728              The Two Towers
# 729              The Two Towers
# 730              The Two Towers
# 731              The Two Towers
#
#                                                Chapter    Race  Character  \
# id
# 1                                         01: Prologue     Elf     Elrond
# 2                                         01: Prologue     Elf  Galadriel
# 3                                         01: Prologue  Gollum     Gollum
# 4                                         01: Prologue  Hobbit      Bilbo
# 5                               02: Concerning Hobbits  Hobbit      Bilbo
# ..                                                 ...     ...        ...
# ...

# %%
df = df.reset_index()

# %%
df
# Out:
#       id                        Film  \
# 0      1  The Fellowship Of The Ring
# 1      2  The Fellowship Of The Ring
# 2      3  The Fellowship Of The Ring
# 3      4  The Fellowship Of The Ring
# 4      5  The Fellowship Of The Ring
# ..   ...                         ...
# 726  727              The Two Towers
# 727  728              The Two Towers
# 728  729              The Two Towers
# 729  730              The Two Towers
# 730  731              The Two Towers
#
#                                                Chapter    Race  Character  \
# 0                                         01: Prologue     Elf     Elrond
# 1                                         01: Prologue     Elf  Galadriel
# 2                                         01: Prologue  Gollum     Gollum
# 3                                         01: Prologue  Hobbit      Bilbo
# 4                               02: Concerning Hobbits  Hobbit      Bilbo
# ...

# %%
df.set_index(i for i in range(1,len(df)+1))
# Out:
#                            Film  \
# 1    The Fellowship Of The Ring
# 2    The Fellowship Of The Ring
# 3    The Fellowship Of The Ring
# 4    The Fellowship Of The Ring
# 5    The Fellowship Of The Ring
# ..                          ...
# 727              The Two Towers
# 728              The Two Towers
# 729              The Two Towers
# 730              The Two Towers
# 731              The Two Towers
#
#                                                Chapter    Race  Character  \
# 1                                         01: Prologue     Elf     Elrond
# 2                                         01: Prologue     Elf  Galadriel
# 3                                         01: Prologue  Gollum     Gollum
# 4                                         01: Prologue  Hobbit      Bilbo
# 5                               02: Concerning Hobbits  Hobbit      Bilbo
# ..                                                 ...     ...        ...
# ...

# %%
df.index.name = 'ID'

# %%
df
# Out:
#                            Film  \
# ID
# 1    The Fellowship Of The Ring
# 2    The Fellowship Of The Ring
# 3    The Fellowship Of The Ring
# 4    The Fellowship Of The Ring
# 5    The Fellowship Of The Ring
# ..                          ...
# 727              The Two Towers
# 728              The Two Towers
# 729              The Two Towers
# 730              The Two Towers
# 731              The Two Towers
#
#                                                Chapter    Race  Character  \
# ID
# 1                                         01: Prologue     Elf     Elrond
# 2                                         01: Prologue     Elf  Galadriel
# 3                                         01: Prologue  Gollum     Gollum
# 4                                         01: Prologue  Hobbit      Bilbo
# 5                               02: Concerning Hobbits  Hobbit      Bilbo
# ..                                                 ...     ...        ...
# ...

# %%
df
# Out:
#                            Film  \
# ID
# 1    The Fellowship Of The Ring
# 2    The Fellowship Of The Ring
# 3    The Fellowship Of The Ring
# 4    The Fellowship Of The Ring
# 5    The Fellowship Of The Ring
# ..                          ...
# 727              The Two Towers
# 728              The Two Towers
# 729              The Two Towers
# 730              The Two Towers
# 731              The Two Towers
#
#                                                Chapter    Race  Character  \
# ID
# 1                                         01: Prologue     Elf     Elrond
# 2                                         01: Prologue     Elf  Galadriel
# 3                                         01: Prologue  Gollum     Gollum
# 4                                         01: Prologue  Hobbit      Bilbo
# 5                               02: Concerning Hobbits  Hobbit      Bilbo
# ..                                                 ...     ...        ...
# ...

# %%
df = df.drop('ID',axis=1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-51-3965f5012c63> in <module>
# ----> 1 df = df.drop('ID',axis=1)
#
# ~\anaconda3\envs\matrix\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4155                 weight  1.0     0.8
#    4156         """
# -> 4157         return super().drop(
#    4158             labels=labels,
#    4159             axis=axis,
#
# ~\anaconda3\envs\matrix\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3876         for axis, labels in axes.items():
#    3877             if labels is not None:
# -> 3878                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    3879
#    3880         if inplace:
#
# ...

# %%
df
# Out:
#                            Film  \
# ID
# 0    The Fellowship Of The Ring
# 1    The Fellowship Of The Ring
# 2    The Fellowship Of The Ring
# 3    The Fellowship Of The Ring
# 4    The Fellowship Of The Ring
# ..                          ...
# 726              The Two Towers
# 727              The Two Towers
# 728              The Two Towers
# 729              The Two Towers
# 730              The Two Towers
#
#                                                Chapter    Race  Character  \
# ID
# 0                                         01: Prologue     Elf     Elrond
# 1                                         01: Prologue     Elf  Galadriel
# 2                                         01: Prologue  Gollum     Gollum
# 3                                         01: Prologue  Hobbit      Bilbo
# 4                               02: Concerning Hobbits  Hobbit      Bilbo
# ..                                                 ...     ...        ...
# ...
