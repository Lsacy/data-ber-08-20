# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('GSAF5.csv', engine='python')

# %%
df.head()
# Out:
#     Case Number       Date  Year        Type    Country      Area  \
# 0  2016.09.18.c  18-Sep-16  2016  Unprovoked        USA   Florida
# 1  2016.09.18.b  18-Sep-16  2016  Unprovoked        USA   Florida
# 2  2016.09.18.a  18-Sep-16  2016  Unprovoked        USA   Florida
# 3    2016.09.17  17-Sep-16  2016  Unprovoked  AUSTRALIA  Victoria
# 4    2016.09.15  16-Sep-16  2016  Unprovoked  AUSTRALIA  Victoria
#
#                            Location Activity             Name Sex   ...  \
# 0  New Smyrna Beach, Volusia County  Surfing             male    M  ...
# 1  New Smyrna Beach, Volusia County  Surfing   Chucky Luciano    M  ...
# 2  New Smyrna Beach, Volusia County  Surfing             male    M  ...
# 3                  Thirteenth Beach  Surfing  Rory Angiolella    M  ...
# 4                       Bells Beach  Surfing             male    M  ...
#
#     Species        Investigator or Source                        pdf  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5992 entries, 0 to 5991
# Data columns (total 24 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Case Number             5992 non-null   object
#  1   Date                    5992 non-null   object
#  2   Year                    5992 non-null   int64
#  3   Type                    5992 non-null   object
#  4   Country                 5949 non-null   object
#  5   Area                    5590 non-null   object
#  6   Location                5496 non-null   object
#  7   Activity                5465 non-null   object
#  8   Name                    5792 non-null   object
#  9   Sex                     5425 non-null   object
#  10  Age                     3311 non-null   object
#  11  Injury                  5965 non-null   object
#  12  Fatal (Y/N)             5973 non-null   object
#  13  Time                    2779 non-null   object
# ...

# %%
# since row 22 and row 23 have only 1 / 2 values out of 5992
    # check the remaining 1,2 values , see if they are important, if not, drop them
df['Unnamed: 22'].fillna(0, inplace=True)
[i for i in df['Unnamed: 22'] if i != 0]
# Out:
# ['stopped here']

# %%
df['Unnamed: 23'].fillna(0, inplace=True)
[i for i in df['Unnamed: 23'] if i != 0]
# Out:
# ['Teramo', 'change filename']

# %%
# Those values seem unimportant, we will drop them
df = df.drop(['Unnamed: 22', 'Unnamed: 23'], axis=1)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5992 entries, 0 to 5991
# Data columns (total 22 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Case Number             5992 non-null   object
#  1   Date                    5992 non-null   object
#  2   Year                    5992 non-null   int64
#  3   Type                    5992 non-null   object
#  4   Country                 5949 non-null   object
#  5   Area                    5590 non-null   object
#  6   Location                5496 non-null   object
#  7   Activity                5465 non-null   object
#  8   Name                    5792 non-null   object
#  9   Sex                     5425 non-null   object
#  10  Age                     3311 non-null   object
#  11  Injury                  5965 non-null   object
#  12  Fatal (Y/N)             5973 non-null   object
#  13  Time                    2779 non-null   object
# ...

# %%
# drop duplicates, if there is any
df = df.drop_duplicates()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5992 entries, 0 to 5991
# Data columns (total 22 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Case Number             5992 non-null   object
#  1   Date                    5992 non-null   object
#  2   Year                    5992 non-null   int64
#  3   Type                    5992 non-null   object
#  4   Country                 5949 non-null   object
#  5   Area                    5590 non-null   object
#  6   Location                5496 non-null   object
#  7   Activity                5465 non-null   object
#  8   Name                    5792 non-null   object
#  9   Sex                     5425 non-null   object
#  10  Age                     3311 non-null   object
#  11  Injury                  5965 non-null   object
#  12  Fatal (Y/N)             5973 non-null   object
#  13  Time                    2779 non-null   object
# ...

# %%
# no duplicates were found

# next I will check the similarities between 'case number', 'case number.1', 'case number.2'

# %%
df['Case Number'].equals(df['Case Number.1'])
# Out:
# False

# %%
df['Case Number'].equals(df['Case Number.2'])
# Out:
# False

# %%
df['Case Number'].isin(df['Case Number.1']).value_counts()
# Out:
# True     5979
# False      13
# Name: Case Number, dtype: int64

# %%
df['Case Number'].isin(df['Case Number.2']).value_counts()
# Out:
# True     5990
# False       2
# Name: Case Number, dtype: int64

# %%
number1 = ~df['Case Number'].isin(df['Case Number.1'])
type(number1)
# Out:
# pandas.core.series.Series

# %%
df[number1][['Case Number','Case Number.1']]
# Out:
#        Case Number Case Number.1
# 4       2016.09.15    2016.09.16
# 33    2016.07.14.4  2016.07.14.R
# 97    2016.01.24.b  2015.01.24.b
# 116     2015.12.23    2015.11.07
# 121   2015.10.28.a    2015.10.28
# 169     2015.07-10    2015.07.10
# 3296    1967.07.05    1967/07.05
# 3569  1962,08.30.b  1962.08.30.b
# 3654  1961.09.02.R  1961.09,06.R
# 4177    1952.08.05    1952.08.04
# 4719  1934.01.08.R  1934.02.08.R
# 5043  1900.00.00.R  1919.00.00.R
# 5150  1911.07.31.R  1911.07.31.T

# %%
# the comparision look very similiar, case number.1 or case number.2 might just some typo, since they wont be relevant for further
# analysis and only takes valueable memory space, we will drop these.

# %%
df = df.drop('Case Number.1', axis=1)

# %%
df = df.drop('Case Number.2', axis=1)

# %%
# lets do the same with href and href formula
df['href'].equals(df['href formula'])
# Out:
# False

# %%
df['href'].isin(df['href formula']).value_counts()
# Out:
# True     5944
# False      48
# Name: href, dtype: int64

# %%
href = ~df['href'].isin(df['href formula'])
df[href][['href','href formula']]
# Out:
#                                                    href  \
# 20    http://sharkattackfile.net/spreadsheets/pdf_di...
# 27    http://sharkattackfile.net/spreadsheets/pdf_di...
# 61    http://sharkattackfile.net/spreadsheets/pdf_di...
# 107   http://sharkattackfile.net/spreadsheets/pdf_di...
# 114   http://sharkattackfile.net/spreadsheets/pdf_di...
# 134   http://sharkattackfile.net/spreadsheets/pdf_di...
# 180   http://sharkattackfile.net/spreadsheets/pdf_di...
# 232   http://sharkattackfile.net/spreadsheets/pdf_di...
# 262   http://sharkattackfile.net/spreadsheets/pdf_di...
# 263   http://sharkattackfile.net/spreadsheets/pdf_di...
# 293   http://sharkattackfile.net/spreadsheets/pdf_di...
# 305   http://sharkattackfile.net/spreadsheets/pdf_di...
# 323   http://sharkattackfile.net/spreadsheets/pdf_di...
# 347   http://sharkattackfile.net/spreadsheets/pdf_di...
# 361   http://sharkattackfile.net/spreadsheets/pdf_di...
# 362   http://sharkattackfile.net/spreadsheets/pdf_di...
# ...

# %%
# change the one value in href to the http link from href formula
df.at[365,'href']  = df.at[365,'href formula']

# %%
# since the difference are minial, less than 10%, I will drop href
df.drop('href formula',axis=1,inplace=True)

# %%
# reset the index and drop the old index and the 'original order' column
df = df.drop('original order',axis=1)
df = df.reset_index(drop=True)

# %%
df.index=range(len(df))

# %%
df.index.name = 'id'
df
# Out:
#        Case Number         Date  Year        Type             Country  \
# id
# 0     2016.09.18.c    18-Sep-16  2016  Unprovoked                 USA
# 1     2016.09.18.b    18-Sep-16  2016  Unprovoked                 USA
# 2     2016.09.18.a    18-Sep-16  2016  Unprovoked                 USA
# 3       2016.09.17    17-Sep-16  2016  Unprovoked           AUSTRALIA
# 4       2016.09.15    16-Sep-16  2016  Unprovoked           AUSTRALIA
# ...            ...          ...   ...         ...                 ...
# 5987       ND.0005  Before 1903     0  Unprovoked           AUSTRALIA
# 5988       ND.0004  Before 1903     0  Unprovoked           AUSTRALIA
# 5989       ND.0003    1900-1905     0  Unprovoked                 USA
# 5990       ND.0002    1883-1889     0  Unprovoked              PANAMA
# 5991       ND.0001    1845-1853     0  Unprovoked  CEYLON (SRI LANKA)
#
#                    Area                             Location      Activity  \
# id
# ...

# %%
# drop [year] column, since [Date] column already contains information on year
df = df.drop('Year', axis=1)

# %%
# now we examine the fatality by looking close to the fatal column
set(df['Fatal (Y/N)'])
# Out:
# {' N', '#VALUE!', 'F', 'N', 'N ', 'UNKNOWN', 'Y', 'n', nan}

# %%
# it contains many different values for essentially 3 types of information: yes, no, unknow , 
df['Fatal (Y/N)'] = df['Fatal (Y/N)'].str.strip()
df['Fatal (Y/N)'] = df['Fatal (Y/N)'].fillna('U')
df['Fatal (Y/N)'] = df['Fatal (Y/N)'].str.replace('n', 'N')
df['Fatal (Y/N)'] = df['Fatal (Y/N)'].str.replace('#VALUE!', 'U')
df['Fatal (Y/N)'] = df['Fatal (Y/N)'].str.replace('N', 'N')
df['Fatal (Y/N)'] = df['Fatal (Y/N)'].str.replace('F', 'Y')
df['Fatal (Y/N)'] = df['Fatal (Y/N)'].str.replace('UNKNOWN', 'U')
df.rename(columns={'Fatal (Y/N)': 'Fatal (Y/N/U)'}, inplace=True)

# %%
set(df['Fatal (Y/N/U)'])
# Out:
# {'N', 'U', 'Y'}

# %%
# now we check for sex
set(df['Sex'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\envs\matrix\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2888             try:
# -> 2889                 return self._engine.get_loc(casted_key)
#    2890             except KeyError as err:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Sex'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-46-dfc1e3706e65> in <module>
#       1 # now we check for sex
# ...

# %%
df.columns
# Out:
# Index(['Case Number', 'Date', 'Type', 'Country', 'Area', 'Location',
#        'Activity', 'Name', 'Sex ', 'Age', 'Injury', 'Fatal (Y/N/U)', 'Time',
#        'Species ', 'Investigator or Source', 'pdf', 'href'],
#       dtype='object')

# %%
df.rename(columns={'Sex ':'Sex'},inplace=True)
df.columns = df.columns.str.strip()

# %%
set(df['Sex'])
# Out:
# {'.', 'F', 'M', 'M ', 'N', 'lli', nan}

# %%
df['Sex'] = df['Sex'].str.strip()
df['Sex'] = df['Sex'].fillna('U')
df['Sex'] = df['Sex'].str.replace('N', 'U')
df['Sex'] = df['Sex'].str.replace('lli', 'U')
df['Sex'] = df['Sex'].str.replace('nan', 'U')
df['Sex'] = df['Sex'].str.replace('.', 'U')

# %%
set(df['Sex'])
# Out:
# {'F', 'M', 'U'}

# %%
# look good now, we will fill the rest of the missing values with unknown - U
df.fillna('U')
# Out:
#        Case Number         Date        Type             Country  \
# id
# 0     2016.09.18.c    18-Sep-16  Unprovoked                 USA
# 1     2016.09.18.b    18-Sep-16  Unprovoked                 USA
# 2     2016.09.18.a    18-Sep-16  Unprovoked                 USA
# 3       2016.09.17    17-Sep-16  Unprovoked           AUSTRALIA
# 4       2016.09.15    16-Sep-16  Unprovoked           AUSTRALIA
# ...            ...          ...         ...                 ...
# 5987       ND.0005  Before 1903  Unprovoked           AUSTRALIA
# 5988       ND.0004  Before 1903  Unprovoked           AUSTRALIA
# 5989       ND.0003    1900-1905  Unprovoked                 USA
# 5990       ND.0002    1883-1889  Unprovoked              PANAMA
# 5991       ND.0001    1845-1853  Unprovoked  CEYLON (SRI LANKA)
#
#                    Area                             Location      Activity  \
# id
# 0               Florida     New Smyrna Beach, Volusia County       Surfing
# ...

# %%
# exporting the table to a new csv file and we are done
df.to_csv('GSF5_clean.csv', index=False)
