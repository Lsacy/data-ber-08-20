# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('GSAF5.csv', engine='python')

# %%
df.sample(10)
# Out:
#        Case Number                  Date  Year        Type    Country  \
# 5195    1908.09.05             05-Sep-08  1908  Unprovoked        USA
# 5983       ND.0009           Before 1906     0  Unprovoked  AUSTRALIA
# 3227    1968.11.02             02-Nov-68  1968    Provoked  AUSTRALIA
# 1491  2003.11.30.b             30-Nov-03  2003  Unprovoked  AUSTRALIA
# 2575    1986.11.30             30-Nov-86  1986  Unprovoked        USA
# 3111  1972.04.01.b             01-Apr-72  1972  Unprovoked  AUSTRALIA
# 2519    1988.03.25             25-Mar-88  1988  Unprovoked        USA
# 1428  2004.07.27.b             27-Jul-04  2004  Unprovoked        USA
# 5403  1895.02.23.R  Reported 23-Feb-1895  1895  Unprovoked     PANAMA
# 3372    1965.12.28             28-Dec-65  1965  Unprovoked  AUSTRALIA
#
#                    Area                                    Location  \
# 5195         California                 Redondo, Los Angeles County
# ...

# %%
df.head(10)
# Out:
#     Case Number       Date  Year        Type        Country  \
# 0  2016.09.18.c  18-Sep-16  2016  Unprovoked            USA
# 1  2016.09.18.b  18-Sep-16  2016  Unprovoked            USA
# 2  2016.09.18.a  18-Sep-16  2016  Unprovoked            USA
# 3    2016.09.17  17-Sep-16  2016  Unprovoked      AUSTRALIA
# 4    2016.09.15  16-Sep-16  2016  Unprovoked      AUSTRALIA
# 5  2016.09.15.R  15-Sep-16  2016        Boat      AUSTRALIA
# 6    2016.09.11  11-Sep-16  2016  Unprovoked            USA
# 7    2016.09.07  07-Sep-16  2016  Unprovoked            USA
# 8    2016.09.06  06-Sep-16  2016  Unprovoked  NEW CALEDONIA
# 9  2016.09.05.b  05-Sep-16  2016  Unprovoked            USA
#
#                 Area                                         Location  \
# 0            Florida                 New Smyrna Beach, Volusia County
# 1            Florida                 New Smyrna Beach, Volusia County
# 2            Florida                 New Smyrna Beach, Volusia County
# ...

# %%
df[['Case Number','Case Number.1','Case Number.2']]
# Out:
#        Case Number Case Number.1 Case Number.2
# 0     2016.09.18.c  2016.09.18.c  2016.09.18.c
# 1     2016.09.18.b  2016.09.18.b  2016.09.18.b
# 2     2016.09.18.a  2016.09.18.a  2016.09.18.a
# 3       2016.09.17    2016.09.17    2016.09.17
# 4       2016.09.15    2016.09.16    2016.09.15
# ...            ...           ...           ...
# 5987       ND.0005       ND.0005       ND.0005
# 5988       ND.0004       ND.0004       ND.0004
# 5989       ND.0003       ND.0003       ND.0003
# 5990       ND.0002       ND.0002       ND.0002
# 5991       ND.0001       ND.0001       ND.0001
#
# [5992 rows x 3 columns]

# %%
df['Case Number.1'].equals(df['Case Number.2'])
# Out:
# False

# %%
df[df['Case Number.1'] != df['Case Number.2']]
# Out:
#        Case Number                                  Date  Year        Type  \
# 4       2016.09.15                             16-Sep-16  2016  Unprovoked
# 33    2016.07.14.4                 Reported  14-Jul-2016  2016  Unprovoked
# 97    2016.01.24.b                             24-Jan-16  2016  Unprovoked
# 116     2015.12.23                             07-Nov-15  2015     Invalid
# 121   2015.10.28.a                             28-Oct-15  2015  Unprovoked
# 3296    1967.07.05                             05-Jul-67  1967  Unprovoked
# 3569  1962,08.30.b                             30-Aug-62  1962        Boat
# 3654  1961.09.02.R                  Reported 06-Sep-1961  1961    Provoked
# 4177    1952.08.05                             05-Aug-52  1952    Provoked
# 5043  1900.00.00.R  Reported to have taken place in 1919  1919     Boating
# 5150  1911.07.31.R                  Reported 31-Jul-1911  1911  Unprovoked
#
# ...

# %%
df['href formula'].equals(df['href'])
# Out:
# False

# %%
keep = [True, True, True, True, True, False, True, True, True, True, True, True, True, True, True, True, True, ]
df[keep]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-26-b5b80e27938c> in <module>
#       1 keep = [True, True, True, True, True, False, True, True, True, True, True, True, True, True, True, True, True, ]
# ----> 2 df[keep]
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2789         # Do we have a (boolean) 1d indexer?
#    2790         if com.is_bool_indexer(key):
# -> 2791             return self._getitem_bool_array(key)
#    2792
#    2793         # We are left with two options: a single key, and a collection of keys,
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in _getitem_bool_array(self, key)
#    2835             )
#    2836         elif len(key) != len(self.index):
# -> 2837             raise ValueError(
# ...
